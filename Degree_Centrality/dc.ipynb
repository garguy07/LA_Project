# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph([(1, 3), (1, 4), (2, 3), (2, 4), (2, 5), (3, 5), (4, 5)])
nx.draw(G, with_labels=True)
nx.degree_centrality(G)
# Out:
# {1: 0.5, 3: 0.75, 4: 0.75, 2: 0.75, 5: 0.75}
